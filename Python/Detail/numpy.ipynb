# %% [markdown]
# # FIRST NOTEBOOK

# %%
a = 10
b = 20
print(a+b)
# Out:
# 30

# %%
from pathlib import Path 
new = Path("lists.py").is_dir() 
print(new)
# Out:
# False

# %%
import numpy as np 
np.array([1,2,34,10])

new_array = np.array([1,3,4,5,6,7,8])
type(new_array)
# Out:
# numpy.ndarray
